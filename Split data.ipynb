# %%
import json
from tqdm import tqdm
import os
path_to_json = 'enwiki20201020/'
for in_file_path in tqdm(os.listdir(path_to_json)[]):
    with open('enwiki20201020/' + str(in_file_path),'r', encoding='utf8') as in_json_file:

        # Read the file and convert it to a dictionary
        json_obj_list = json.load(in_json_file)

        for json_obj in json_obj_list:
            if (json_obj['id'] == '13205523'):
                print(in_file_path)
# Out:
#   6%|█████▏                                                                           | 39/605 [00:23<05:44,  1.64it/s]
# 104d9c4d-866f-4bde-bd8f-a283dbd221a8.json
#  70%|████████████████████████████████████████████████████████                        | 424/605 [04:29<01:55,  1.57it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [21], in <module>
#       5 for in_file_path in tqdm(os.listdir(path_to_json)):
#       6     with open('enwiki20201020/' + str(in_file_path),'r', encoding='utf8') as in_json_file:
#       7
#       8         # Read the file and convert it to a dictionary
# ----> 9         json_obj_list = json.load(in_json_file)
#      11         for json_obj in json_obj_list:
#      12             if (json_obj['id'] == '13205523'):
#
# ...

# %%
lista = [os.listdir(path_to_json)[39], os.listdir(path_to_json)[40] , os.listdir(path_to_json)[41],os.listdir(path_to_json)[42]]

# %%
for in_file_path in ('enwiki20201020/'104d9c4d-866f-4bde-bd8f-a283dbd221a8.json)):
# Out:
#   Input In [36]
#     for in_file_path in ('enwiki20201020/'104d9c4d-866f-4bde-bd8f-a283dbd221a8.json)):
#                                           ^
# SyntaxError: invalid syntax

# %%
ids =[]
path_to_json = 'enwiki20201020/'
for in_file_path in tqdm(os.listdir(path_to_json)[0:38]):
    with open('enwiki20201020/'+str(in_file_path),'r', encoding='utf8') as in_json_file:
            # Read the file and convert it to a dictionary
            json_obj_list = json.load(in_json_file)
            for json_obj in json_obj_list:
                ids.append(str(json_obj['id'])+'.json')
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 38/38 [00:23<00:00,  1.60it/s]

# %%
ids
# Out:
# 371627

# %%
from pymongo import MongoClient
client = MongoClient("mongodb+srv://admin:admin@cluster0.wjk47.mongodb.net/WikepediaMetadatas?ssl=true&ssl_cert_reqs=CERT_NONE")

client.list_database_names()

#database 
db = client["WikepediaMetadatas"]
   
# Created or Switched to collection 
# names: GeeksForGeeks
Collection = db["Metadatas_Raw"]

for i in ids:
    myquery = { "file_name": i }
    print(myquery)
    Collection.delete_one(myquery)
# Out:
# {'file_name': '47070226.json'}
# {'file_name': '47070228.json'}
# {'file_name': '47070233.json'}
# {'file_name': '47070262.json'}
# {'file_name': '47070266.json'}
# {'file_name': '47070278.json'}
# {'file_name': '47070281.json'}
# {'file_name': '47070287.json'}
# {'file_name': '47070327.json'}
# {'file_name': '47070343.json'}
# {'file_name': '47070364.json'}
# {'file_name': '47070370.json'}
# {'file_name': '47070373.json'}
# {'file_name': '47070378.json'}
# {'file_name': '47070382.json'}
# {'file_name': '47070388.json'}
# {'file_name': '47070406.json'}
# {'file_name': '47070420.json'}
# {'file_name': '47070423.json'}
# {'file_name': '47070431.json'}
# {'file_name': '47070450.json'}
# {'file_name': '47070456.json'}
# {'file_name': '47070458.json'}
# {'file_name': '47070509.json'}
# {'file_name': '47070537.json'}
# {'file_name': '47070574.json'}
# {'file_name': '47070586.json'}
# {'file_name': '47070592.json'}
# {'file_name': '47070593.json'}
# {'file_name': '47070595.json'}
# ...

# %%
for f in ids:
    os.remove('enwiki2020/'+str(f))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [38], in <module>
#       1 for f in ids:
# ----> 2     os.remove('enwiki2020/'+str(f))
#
# FileNotFoundError: [WinError 2] The system cannot find the file specified: 'enwiki2020/7952650.json'

# %%
filename=json_obj['id']+'.json'
            with open('./enwiki2020-clean/'+ str(filename.replace('.json', '')+'-clean.json', 'w') as out_json_file:
                # Save each obj to their respective filepath
                # with pretty formatting thanks to `indent=4`
                json.dump(json_obj, out_json_file, indent=4)

# %%
path_to_json = 'enwiki2020/'
os.listdir(path_to_json)[30000]
# Out:
# '13229471.json'
